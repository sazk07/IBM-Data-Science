# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shahan Arshad**
#
# Data Analyst

# %% [markdown]
# *I am interested in Data Science to help me get my PhD*

# %% [markdown]
# ### This code is supposed to print "Hello from the other side :)"

# %%
print ("Hello from the other side :)")
# Out:
# Hello from the other side :)

# %% [markdown]
# Bulleted list:
#
# - Python
#     * PyQt
#     * Flask
#     * Pandas
# - Java
#     * Hibernate
#     * Spring
#  - PHP
#  - ruby
#
#  Hyperlinks:
#
#  [Home page of Project Jupyter](https://jupyter.org "Project Jupyter")
#
#  [Gmail](https://www.gmail.com)
#
#  Image:
#
#  ![random image](./1097071.jpg)
